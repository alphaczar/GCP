# %%
import os
import json
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "C:/Users/ajay/Downloads/mykey.json"

# %% [markdown]
# ### Analyzing Entity in a String

# %%
from google.cloud import language_v1
from google.cloud.language_v1 import enums

def sample_analyze_entities(text_content):
    """
    Analyzing Entities in a String

    Args:
      text_content The text content to analyze
    """

    client = language_v1.LanguageServiceClient()

    # text_content = 'California is a state.'

    # Available types: PLAIN_TEXT, HTML
    type_ = enums.Document.Type.PLAIN_TEXT

    # Optional. If not specified, the language is automatically detected.
    # For list of supported languages:
    # https://cloud.google.com/natural-language/docs/languages
    language = "en"
    document = {"content": text_content, "type": type_, "language": language}

    # Available values: NONE, UTF8, UTF16, UTF32
    encoding_type = enums.EncodingType.UTF8

    response = client.analyze_entities(document, encoding_type=encoding_type)

    # Loop through entitites returned from the API
    for entity in response.entities:
        print(u"Representative name for the entity: {}".format(entity.name))

        # Get entity type, e.g. PERSON, LOCATION, ADDRESS, NUMBER, et al
        print(u"Entity type: {}".format(enums.Entity.Type(entity.type).name))

        # Get the salience score associated with the entity in the [0, 1.0] range
        print(u"Salience score: {}".format(entity.salience))

        # Loop over the metadata associated with entity. For many known entities,
        # the metadata is a Wikipedia URL (wikipedia_url) and Knowledge Graph MID (mid).
        # Some entity types may have additional metadata, e.g. ADDRESS entities
        # may have metadata for the address street_name, postal_code, et al.
        for metadata_name, metadata_value in entity.metadata.items():
            print(u"{}: {}".format(metadata_name, metadata_value))

        # Loop over the mentions of this entity in the input document.
        # The API currently supports proper noun mentions.
        for mention in entity.mentions:
            print(u"Mention text: {}".format(mention.text.content))

            # Get the mention type, e.g. PROPER for proper noun
            print(
                u"Mention type: {}".format(enums.EntityMention.Type(mention.type).name)
            )

    # Get the language of the text, which will be the same as
    # the language specified in the request or, if not specified,
    # the automatically-detected language.
    print(u"Language of the text: {}".format(response.language))

# %%
sample_analyze_entities('European authorities fined Google a record $5.1 billion on Wednesday for abusing its power in the mobile phone market and ordered the company to alter its practices')
# Out:
# Representative name for the entity: Google
# Entity type: ORGANIZATION
# Salience score: 0.5137450098991394
# wikipedia_url: https://en.wikipedia.org/wiki/Google
# mid: /m/045c7b
# Mention text: Google
# Mention type: PROPER
# Representative name for the entity: authorities
# Entity type: PERSON
# Salience score: 0.22009794414043427
# Mention text: authorities
# Mention type: COMMON
# Representative name for the entity: European
# Entity type: LOCATION
# Salience score: 0.12270887196063995
# wikipedia_url: https://en.wikipedia.org/wiki/Europe
# mid: /m/02j9z
# Mention text: European
# Mention type: PROPER
# Representative name for the entity: power
# Entity type: OTHER
# Salience score: 0.0570954866707325
# Mention text: power
# Mention type: COMMON
# Representative name for the entity: company
# Entity type: ORGANIZATION
# Salience score: 0.04008486866950989
# Mention text: company
# Mention type: COMMON
# Representative name for the entity: practices
# Entity type: OTHER
# Salience score: 0.02834763377904892
# Mention text: practices
# Mention type: COMMON
# Representative name for the entity: mobile phone market
# Entity type: OTHER
# Salience score: 0.017920179292559624
# Mention text: mobile phone market
# Mention type: COMMON
# Representative name for the entity: $5.1 billion
# Entity type: PRICE
# Salience score: 0.0
# value: 5100000000.000000
# currency: USD
# Mention text: $5.1 billion
# Mention type: TYPE_UNKNOWN
# Representative name for the entity: 5.1 billion
# Entity type: NUMBER
# Salience score: 0.0
# value: 5100000000.000000
# Mention text: 5.1 billion
# Mention type: TYPE_UNKNOWN
# Language of the text: en

# %%
sample_analyze_entities("The Skoda Kodiaq TSI petrol BS6 was scheduled to go on sale in India in later this year as part of the five new and updated model launches by the brand in 2020. However, the coronavirus pandemic put things off the rail and delayed the launch proceedings for some models.")
# Out:
# Representative name for the entity: BS6
# Entity type: OTHER
# Salience score: 0.6070741415023804
# Mention text: BS6
# Mention type: PROPER
# Mention text: petrol
# Mention type: COMMON
# Representative name for the entity: Skoda Kodiaq TSI
# Entity type: ORGANIZATION
# Salience score: 0.09760183840990067
# Mention text: Skoda Kodiaq TSI
# Mention type: PROPER
# Representative name for the entity: sale
# Entity type: OTHER
# Salience score: 0.06424079090356827
# Mention text: sale
# Mention type: COMMON
# Representative name for the entity: model launches
# Entity type: OTHER
# Salience score: 0.04648905619978905
# Mention text: model launches
# Mention type: COMMON
# Representative name for the entity: part
# Entity type: OTHER
# Salience score: 0.04404826462268829
# Mention text: part
# Mention type: COMMON
# Representative name for the entity: brand
# Entity type: ORGANIZATION
# Salience score: 0.041012734174728394
# Mention text: brand
# Mention type: COMMON
# Representative name for the entity: India
# Entity type: LOCATION
# Salience score: 0.038760021328926086
# wikipedia_url: https://en.wikipedia.org/wiki/India
# mid: /m/03rk0
# Mention text: India
# Mention type: PROPER
# Representative name for the entity: things
# Entity type: OTHER
# Salience score: 0.01512538455426693
# Mention text: things
# Mention type: COMMON
# Representative name for the entity: rail
# Entity type: OTHER
# Salience score: 0.01512538455426693
# Mention text: rail
# Mention type: COMMON
# Representative name for the entity: models
# Entity type: CONSUMER_GOOD
# Salience score: 0.012078944593667984
# Mention text: models
# Mention type: COMMON
# Representative name for the entity: launch proceedings
# Entity type: EVENT
# Salience score: 0.010620423592627048
# Mention text: launch proceedings
# Mention type: COMMON
# Representative name for the entity: coronavirus pandemic
# Entity type: OTHER
# Salience score: 0.007823042571544647
# Mention text: coronavirus pandemic
# Mention type: COMMON
# Representative name for the entity: 2020
# Entity type: DATE
# Salience score: 0.0
# year: 2020
# Mention text: 2020
# Mention type: TYPE_UNKNOWN
# Representative name for the entity: BS6
# Entity type: PRICE
# Salience score: 0.0
# value: 6.000000
# currency: VEB
# Mention text: BS6
# Mention type: TYPE_UNKNOWN
# Representative name for the entity: 2020
# Entity type: NUMBER
# Salience score: 0.0
# value: 2020
# Mention text: 2020
# Mention type: TYPE_UNKNOWN
# Representative name for the entity: five
# Entity type: NUMBER
# Salience score: 0.0
# value: 5
# Mention text: five
# Mention type: TYPE_UNKNOWN
# Language of the text: en

# %% [markdown]
# ### Analyzing Entity of a text file from Google Storage

# %%
from google.cloud import language_v1
from google.cloud.language_v1 import enums


def sample_analyze_entities2(gcs_content_uri):
    """
    Analyzing Entities in text file stored in Cloud Storage

    Args:
      gcs_content_uri Google Cloud Storage URI where the file content is located.
      e.g. gs://[Your Bucket]/[Path to File]
    """

    client = language_v1.LanguageServiceClient()

    # gcs_content_uri = 'gs://cloud-samples-data/language/entity.txt'

    # Available types: PLAIN_TEXT, HTML
    type_ = enums.Document.Type.PLAIN_TEXT

    # Optional. If not specified, the language is automatically detected.
    # For list of supported languages:
    # https://cloud.google.com/natural-language/docs/languages
    language = "en"
    document = {"gcs_content_uri": gcs_content_uri, "type": type_, "language": language}

    # Available values: NONE, UTF8, UTF16, UTF32
    encoding_type = enums.EncodingType.UTF8

    response = client.analyze_entities(document, encoding_type=encoding_type)
    # Loop through entitites returned from the API
    for entity in response.entities:
        print(u"Representative name for the entity: {}".format(entity.name))
        # Get entity type, e.g. PERSON, LOCATION, ADDRESS, NUMBER, et al
        print(u"Entity type: {}".format(enums.Entity.Type(entity.type).name))
        # Get the salience score associated with the entity in the [0, 1.0] range
        print(u"Salience score: {}".format(entity.salience))
        # Loop over the metadata associated with entity. For many known entities,
        # the metadata is a Wikipedia URL (wikipedia_url) and Knowledge Graph MID (mid).
        # Some entity types may have additional metadata, e.g. ADDRESS entities
        # may have metadata for the address street_name, postal_code, et al.
        for metadata_name, metadata_value in entity.metadata.items():
            print(u"{}: {}".format(metadata_name, metadata_value))

        # Loop over the mentions of this entity in the input document.
        # The API currently supports proper noun mentions.
        for mention in entity.mentions:
            print(u"Mention text: {}".format(mention.text.content))
            # Get the mention type, e.g. PROPER for proper noun
            print(
                u"Mention type: {}".format(enums.EntityMention.Type(mention.type).name)
            )

    # Get the language of the text, which will be the same as
    # the language specified in the request or, if not specified,
    # the automatically-detected language.
    print(u"Language of the text: {}".format(response.language))

# %%
sample_analyze_entities2('gs://buck910/gcp_nlp.txt')
# Out:
# Representative name for the entity: The American Association for the Advancement of Science
# Entity type: ORGANIZATION
# Salience score: 0.2911573648452759
# wikipedia_url: https://en.wikipedia.org/wiki/American_Association_for_the_Advancement_of_Science
# mid: /m/01k85s
# Mention text: The American Association for the Advancement of Science
# Mention type: PROPER
# Mention text: publisher
# Mention type: COMMON
# Mention text: AAAS
# Mention type: PROPER
# Mention text: AAAS
# Mention type: PROPER
# Mention text: AAAS
# Mention type: PROPER
# Representative name for the entity: move
# Entity type: EVENT
# Salience score: 0.1562243551015854
# Mention text: move
# Mention type: COMMON
# Representative name for the entity: scientists
# Entity type: PERSON
# Salience score: 0.07693222165107727
# Mention text: scientists
# Mention type: COMMON
# Representative name for the entity: Science journals
# Entity type: OTHER
# Salience score: 0.05370168015360832
# Mention text: Science journals
# Mention type: COMMON
# Representative name for the entity: sciences
# Entity type: OTHER
# Salience score: 0.04537392035126686
# Mention text: sciences
# Mention type: COMMON
# Representative name for the entity: letter
# Entity type: WORK_OF_ART
# Salience score: 0.03969138488173485
# Mention text: letter
# Mention type: COMMON
# Representative name for the entity: strike
# Entity type: EVENT
# Salience score: 0.039452556520700455
# Mention text: strike
# Mention type: COMMON
# Representative name for the entity: academia
# Entity type: ORGANIZATION
# Salience score: 0.032101985067129135
# Mention text: academia
# Mention type: COMMON
# Representative name for the entity: plan
# Entity type: OTHER
# Salience score: 0.02939220890402794
# Mention text: plan
# Mention type: COMMON
# Representative name for the entity: Black
# Entity type: PERSON
# Salience score: 0.028173480182886124
# Mention text: Black
# Mention type: PROPER
# Representative name for the entity: racism
# Entity type: OTHER
# Salience score: 0.024863606318831444
# Mention text: racism
# Mention type: COMMON
# Representative name for the entity: Sudip Parikh
# Entity type: PERSON
# Salience score: 0.02203369140625
# mid: /g/11f0yx5l7k
# Mention text: Sudip Parikh
# Mention type: PROPER
# Mention text: CEO
# Mention type: COMMON
# Representative name for the entity: institution
# Entity type: ORGANIZATION
# Salience score: 0.01884961873292923
# Mention text: institution
# Mention type: COMMON
# Representative name for the entity: members
# Entity type: PERSON
# Salience score: 0.01569114439189434
# Mention text: members
# Mention type: COMMON
# Representative name for the entity: sciences
# Entity type: OTHER
# Salience score: 0.015417846851050854
# Mention text: sciences
# Mention type: COMMON
# Representative name for the entity: data
# Entity type: OTHER
# Salience score: 0.012525329366326332
# Mention text: data
# Mention type: COMMON
# Representative name for the entity: journals
# Entity type: WORK_OF_ART
# Salience score: 0.008621546439826488
# Mention text: journals
# Mention type: COMMON
# Representative name for the entity: staff
# Entity type: PERSON
# Salience score: 0.00757504953071475
# Mention text: staff
# Mention type: COMMON
# Representative name for the entity: fellows
# Entity type: PERSON
# Salience score: 0.00757504953071475
# Mention text: fellows
# Mention type: COMMON
# Representative name for the entity: authors
# Entity type: PERSON
# Salience score: 0.00757504953071475
# Mention text: authors
# Mention type: COMMON
# Representative name for the entity: diversity
# Entity type: OTHER
# Salience score: 0.00757504953071475
# Mention text: diversity
# Mention type: COMMON
# Representative name for the entity: June 10th
# Entity type: DATE
# Salience score: 0.0
# month: 6
# day: 10
# Mention text: June 10th
# Mention type: TYPE_UNKNOWN
# Representative name for the entity: 10
# Entity type: NUMBER
# Salience score: 0.0
# value: 10
# Mention text: 10
# Mention type: TYPE_UNKNOWN
# Representative name for the entity: 120,000
# Entity type: NUMBER
# Salience score: 0.0
# value: 120000
# Mention text: 120,000
# Mention type: TYPE_UNKNOWN
# Representative name for the entity: 172
# Entity type: NUMBER
# Salience score: 0.0
# value: 172
# Mention text: 172
# Mention type: TYPE_UNKNOWN
# Language of the text: en

# %% [markdown]
# ### Analyzing Entity of a PDF file from Google Storage

# %%
def Sent_PDF(gcs_source_uri, gcs_destination_uri):
    """OCR with PDF/TIFF as source files on GCS"""

    import re
    from google.cloud import vision
    from google.cloud import storage
    from google.protobuf import json_format
    # Supported mime_types are: 'application/pdf' and 'image/tiff'
    mime_type = 'application/pdf'

    # How many pages should be grouped into each json output file.
    batch_size = 1

    client = vision.ImageAnnotatorClient()

    feature = vision.types.Feature(
        type=vision.enums.Feature.Type.DOCUMENT_TEXT_DETECTION)

    gcs_source = vision.types.GcsSource(uri='gs://buck910/Review1.pdf')
    input_config = vision.types.InputConfig(
        gcs_source=gcs_source, mime_type=mime_type)

    gcs_destination = vision.types.GcsDestination(uri=gcs_destination_uri)
    output_config = vision.types.OutputConfig(
        gcs_destination=gcs_destination, batch_size=batch_size)

    async_request = vision.types.AsyncAnnotateFileRequest(
        features=[feature], input_config=input_config,
        output_config=output_config)

    operation = client.async_batch_annotate_files(
        requests=[async_request])

    print('Waiting for the operation to finish.')
    operation.result(timeout=420)

    # Once the request has completed and the output has been
    # written to GCS, we can list all the output files.
    storage_client = storage.Client()

    match = re.match(r'gs://([^/]+)/(.+)', gcs_destination_uri)
    bucket_name = match.group(1)
    prefix = match.group(2)

    bucket = storage_client.get_bucket(bucket_name)

    # List objects with the given prefix.
    blob_list = list(bucket.list_blobs(prefix=prefix))
    print('Output files:')
    for blob in blob_list:
        print(blob.name)

    # Process the first output file from GCS.
    # Since we specified batch_size=2, the first response contains
    # the first two pages of the input file.
    output = blob_list[0]

    json_string = output.download_as_string()
    response = json_format.Parse(
        json_string, vision.types.AnnotateFileResponse())

    # The actual response for the first page of the input file.
    first_page_response = response.responses[0]
    annotation = first_page_response.full_text_annotation

    # Here we print the full text from the first page.
    # The response contains more information:
    # annotation/pages/blocks/paragraphs/words/symbols
    # including confidence scores and bounding boxes
    print(u'Full text:\n{}'.format(
        annotation.text))
    sent_text = annotation.text
    sample_analyze_entities(sent_text)

# %%
Sent_PDF('gs://buck910/SampleTest (1).pdf','gs://buck910/nlp_entityout.json')
# Out:
# Waiting for the operation to finish.
# Output files:
# nlp_entityout.jsonoutput-1-to-1.json
# Full text:
# Cons
# I would say the biggest issue that I have simply revolves around how much we've
# grown in such a short amount of time. Being a new employee in Professional Services
# has been tough and would have been impossible without my amazing team. There's so
# MUCH information out there in various tools that there's just no way a person can
# understand where to go and possibly consume it all. A lot of relevant information is
# buried under irrelevant information. New tools come out, are exciting for a bit, then die
# away. The second largest issue in my mind is that the goals and desires of the
# Professional Services organization do not jive AT ALL with the goals and desires of my
# particular client. Now, I know that I have tunnel vision and that I haven't had enough
# experience with any other clients yet - I'm sure that with more time and exposure,
# more insights will occur. But I really feel like the work that I'm doing for my client has
# no relation to the goals of the overall organization. Here's the thing though - I know
# that improvement to these areas are in the works. It takes time to think through the
# best ways to deal with these issues and I have faith that the time will come where
# these cons won't be listed here anymore and new cons will take their place.
# Show Less
# Advice to Management
# Please continue to be transparent. Please continue to help us make organization
# changes that lead to better outcomes for our clients and ourselves. But mostly, please
# continue to invest in us the employees. I've watched these folks make miracles happen
# for you to help you achieve your goals and dreams. Putting your employees first is what
# allows us to be great - I sincerely and deeply hope that will always continue going
# forward.
#
# Representative name for the entity: issue
# Entity type: OTHER
# Salience score: 0.22702130675315857
# Mention text: issue
# Mention type: COMMON
# Representative name for the entity: amount
# Entity type: OTHER
# Salience score: 0.07363583892583847
# Mention text: amount
# Mention type: COMMON
# Representative name for the entity: goals
# Entity type: OTHER
# Salience score: 0.05665598064661026
# Mention text: goals
# Mention type: COMMON
# Mention text: goals
# Mention type: COMMON
# Representative name for the entity: employee
# Entity type: PERSON
# Salience score: 0.044358059763908386
# Mention text: employee
# Mention type: COMMON
# Representative name for the entity: employees
# Entity type: PERSON
# Salience score: 0.036767516285181046
# Mention text: employees
# Mention type: COMMON
# Representative name for the entity: way
# Entity type: OTHER
# Salience score: 0.03422452509403229
# Mention text: way
# Mention type: COMMON
# Representative name for the entity: Cons
# Entity type: OTHER
# Salience score: 0.0329631008207798
# Mention text: Cons
# Mention type: COMMON
# Representative name for the entity: work
# Entity type: OTHER
# Salience score: 0.028333965688943863
# Mention text: work
# Mention type: COMMON
# Representative name for the entity: Professional Services
# Entity type: ORGANIZATION
# Salience score: 0.02400347776710987
# wikipedia_url: https://en.wikipedia.org/wiki/Professional_services
# mid: /m/04fbtd
# Mention text: Professional Services
# Mention type: PROPER
# Mention text: Professional Services
# Mention type: PROPER
# Representative name for the entity: information
# Entity type: OTHER
# Salience score: 0.020171258598566055
# Mention text: information
# Mention type: COMMON
# Representative name for the entity: information
# Entity type: OTHER
# Salience score: 0.01672157272696495
# Mention text: information
# Mention type: COMMON
# Representative name for the entity: information
# Entity type: OTHER
# Salience score: 0.01672157272696495
# Mention text: information
# Mention type: COMMON
# Representative name for the entity: tools
# Entity type: OTHER
# Salience score: 0.015308631584048271
# Mention text: tools
# Mention type: COMMON
# Representative name for the entity: organization changes
# Entity type: OTHER
# Salience score: 0.013583504594862461
# Mention text: organization
# changes
# Mention type: COMMON
# Representative name for the entity: team
# Entity type: ORGANIZATION
# Salience score: 0.013516959734261036
# Mention text: team
# Mention type: COMMON
# Representative name for the entity: issue
# Entity type: OTHER
# Salience score: 0.013504218310117722
# Mention text: issue
# Mention type: COMMON
# Representative name for the entity: tools
# Entity type: CONSUMER_GOOD
# Salience score: 0.01345498114824295
# Mention text: tools
# Mention type: COMMON
# Representative name for the entity: lot
# Entity type: OTHER
# Salience score: 0.01340237632393837
# Mention text: lot
# Mention type: COMMON
# Representative name for the entity: cons
# Entity type: OTHER
# Salience score: 0.012964747846126556
# Mention text: cons
# Mention type: COMMON
# Representative name for the entity: client
# Entity type: PERSON
# Salience score: 0.012210525572299957
# Mention text: client
# Mention type: COMMON
# Representative name for the entity: clients
# Entity type: PERSON
# Salience score: 0.012187423184514046
# Mention text: clients
# Mention type: COMMON
# Representative name for the entity: goals
# Entity type: OTHER
# Salience score: 0.01206143107265234
# Mention text: goals
# Mention type: COMMON
# Representative name for the entity: organization
# Entity type: ORGANIZATION
# Salience score: 0.011231565847992897
# Mention text: organization
# Mention type: COMMON
# Representative name for the entity: insights
# Entity type: OTHER
# Salience score: 0.011207304894924164
# Mention text: insights
# Mention type: COMMON
# Representative name for the entity: client
# Entity type: PERSON
# Salience score: 0.01116469781845808
# Mention text: client
# Mention type: COMMON
# Representative name for the entity: organization
# Entity type: ORGANIZATION
# Salience score: 0.010396390222012997
# Mention text: organization
# Mention type: COMMON
# Representative name for the entity: desires
# Entity type: OTHER
# Salience score: 0.010371880605816841
# Mention text: desires
# Mention type: COMMON
# Representative name for the entity: desires
# Entity type: OTHER
# Salience score: 0.010245186276733875
# Mention text: desires
# Mention type: COMMON
# Representative name for the entity: ALL
# Entity type: OTHER
# Salience score: 0.010245186276733875
# Mention text: ALL
# Mention type: COMMON
# Representative name for the entity: thing
# Entity type: OTHER
# Salience score: 0.010002857074141502
# Mention text: thing
# Mention type: COMMON
# Representative name for the entity: person
# Entity type: PERSON
# Salience score: 0.009302935563027859
# Mention text: person
# Mention type: COMMON
# Representative name for the entity: Advice
# Entity type: OTHER
# Salience score: 0.00915552582591772
# Mention text: Advice
# Mention type: COMMON
# Representative name for the entity: exposure
# Entity type: OTHER
# Salience score: 0.009094051085412502
# Mention text: exposure
# Mention type: COMMON
# Representative name for the entity: experience
# Entity type: OTHER
# Salience score: 0.009094051085412502
# Mention text: experience
# Mention type: COMMON
# Representative name for the entity: bit
# Entity type: OTHER
# Salience score: 0.009020171128213406
# Mention text: bit
# Mention type: COMMON
# Representative name for the entity: mind
# Entity type: OTHER
# Salience score: 0.008999975398182869
# Mention text: mind
# Mention type: COMMON
# Representative name for the entity: tunnel vision
# Entity type: OTHER
# Salience score: 0.008982935920357704
# Mention text: tunnel vision
# Mention type: COMMON
# Representative name for the entity: miracles
# Entity type: OTHER
# Salience score: 0.008375667966902256
# Mention text: miracles
# Mention type: COMMON
# Representative name for the entity: clients
# Entity type: PERSON
# Salience score: 0.008373373188078403
# Mention text: clients
# Mention type: COMMON
# Representative name for the entity: relation
# Entity type: OTHER
# Salience score: 0.008330438286066055
# Mention text: relation
# Mention type: COMMON
# Representative name for the entity: areas
# Entity type: LOCATION
# Salience score: 0.008318382315337658
# Mention text: areas
# Mention type: COMMON
# Representative name for the entity: improvement
# Entity type: OTHER
# Salience score: 0.008116311393678188
# Mention text: improvement
# Mention type: COMMON
# Representative name for the entity: faith
# Entity type: OTHER
# Salience score: 0.0069244857877492905
# Mention text: faith
# Mention type: COMMON
# Representative name for the entity: Management
# Entity type: OTHER
# Salience score: 0.006253437139093876
# Mention text: Management
# Mention type: COMMON
# Representative name for the entity: outcomes
# Entity type: OTHER
# Salience score: 0.006246747449040413
# Mention text: outcomes
# Mention type: COMMON
# Representative name for the entity: goals
# Entity type: OTHER
# Salience score: 0.005850252695381641
# Mention text: goals
# Mention type: COMMON
# Representative name for the entity: employees
# Entity type: PERSON
# Salience score: 0.0054426053538918495
# Mention text: employees
# Mention type: COMMON
# Representative name for the entity: time
# Entity type: OTHER
# Salience score: 0.0048247757367789745
# Mention text: time
# Mention type: COMMON
# Representative name for the entity: dreams
# Entity type: OTHER
# Salience score: 0.00436382507905364
# Mention text: dreams
# Mention type: COMMON
# Representative name for the entity: folks
# Entity type: PERSON
# Salience score: 0.00436382507905364
# Mention text: folks
# Mention type: COMMON
# Representative name for the entity: cons
# Entity type: OTHER
# Salience score: 0.0034267264418303967
# Mention text: cons
# Mention type: COMMON
# Representative name for the entity: issues
# Entity type: OTHER
# Salience score: 0.0034267264418303967
# Mention text: issues
# Mention type: COMMON
# Representative name for the entity: place
# Entity type: OTHER
# Salience score: 0.003142981557175517
# Mention text: place
# Mention type: COMMON
# Representative name for the entity: works
# Entity type: WORK_OF_ART
# Salience score: 0.00312937144190073
# Mention text: works
# Mention type: COMMON
# Representative name for the entity: ways
# Entity type: OTHER
# Salience score: 0.0027449417393654585
# Mention text: ways
# Mention type: COMMON
# Language of the text: en

# %% [markdown]
# ### Analyzing Entity of a PDF file from local

# %%
from google.cloud import vision
import io

def analyze_pdf(pdf_file):
    from google.cloud.vision import enums
    client = vision.ImageAnnotatorClient()
    
    mime_type = "application/pdf"
    with io.open(pdf_file, "rb") as f:
        content = f.read()
    input_config = {"mime_type": mime_type, "content": content}
    features = [{"type": enums.Feature.Type.DOCUMENT_TEXT_DETECTION}]

    pages = [1, 2, -1]
    requests = [{"input_config": input_config, "features": features, "pages": pages}]

    from google.cloud.language import enums
    
    response = client.batch_annotate_files(requests)
    for image_response in response.responses[0].responses:
        test=format(image_response.full_text_annotation.text)
    content = test.replace('\n','')
    
   
    client = language_v1.LanguageServiceClient()
    type_ = enums.Document.Type.PLAIN_TEXT
    language = "en"
    document = {"content": content, "type": type_, "language": language}

    # Available values: NONE, UTF8, UTF16, UTF32
    encoding_type = enums.EncodingType.UTF8

    response = client.analyze_entities(document, encoding_type=encoding_type)
    for entity in response.entities:
        print(u"Representative name for the entity: {}".format(entity.name))

        
        print(u"Entity type: {}".format(enums.Entity.Type(entity.type).name))

        # Get the salience score associated with the entity in the [0, 1.0] range
        print(u"Salience score: {}".format(entity.salience))
        for metadata_name, metadata_value in entity.metadata.items():
            print(u"{}: {}".format(metadata_name, metadata_value))
        for mention in entity.mentions:
            print(u"Mention text: {}".format(mention.text.content))
            print(
                u"Mention type: {}".format(enums.EntityMention.Type(mention.type).name)
            )

    print(u"Language of the text: {}".format(response.language))

# %%
analyze_pdf('C:\\Users\\ajay\\Documents\\nlp\\SampleTest.pdf')
# Out:
# Representative name for the entity: networks
# Entity type: OTHER
# Salience score: 0.24651819467544556
# Mention text: networks
# Mention type: COMMON
# Mention text: networks
# Mention type: COMMON
# Mention text: networks
# Mention type: COMMON
# Mention text: networks
# Mention type: COMMON
# Mention text: networks
# Mention type: COMMON
# Mention text: networks
# Mention type: COMMON
# Mention text: networks
# Mention type: COMMON
# Representative name for the entity: networks
# Entity type: OTHER
# Salience score: 0.06832458823919296
# Mention text: networks
# Mention type: COMMON
# Representative name for the entity: book
# Entity type: WORK_OF_ART
# Salience score: 0.05301626771688461
# Mention text: book
# Mention type: COMMON
# Representative name for the entity: learning
# Entity type: OTHER
# Salience score: 0.04913756996393204
# Mention text: learning
# Mention type: COMMON
# Mention text: learning
# Mention type: COMMON
# Mention text: learning
# Mention type: COMMON
# Mention text: learning
# Mention type: COMMON
# Mention text: learning
# Mention type: COMMON
# Representative name for the entity: one
# Entity type: PERSON
# Salience score: 0.0375196635723114
# Mention text: one
# Mention type: COMMON
# Representative name for the entity: tasks
# Entity type: OTHER
# Salience score: 0.03639749065041542
# Mention text: tasks
# Mention type: COMMON
# Representative name for the entity: programming paradigms
# Entity type: OTHER
# Salience score: 0.029782205820083618
# Mention text: programming paradigms
# Mention type: COMMON
# Representative name for the entity: network
# Entity type: OTHER
# Salience score: 0.025910189375281334
# Mention text: network
# Mention type: COMMON
# Representative name for the entity: data
# Entity type: OTHER
# Salience score: 0.024452317506074905
# Mention text: data
# Mention type: COMMON
# Mention text: data
# Mention type: COMMON
# Representative name for the entity: problems
# Entity type: OTHER
# Salience score: 0.023172099143266678
# Mention text: problems
# Mention type: COMMON
# Representative name for the entity: programming
# Entity type: OTHER
# Salience score: 0.017909342423081398
# Mention text: programming
# Mention type: COMMON
# Representative name for the entity: approach
# Entity type: OTHER
# Salience score: 0.017909342423081398
# Mention text: approach
# Mention type: COMMON
# Representative name for the entity: aboutNeural
# Entity type: OTHER
# Salience score: 0.01767745055258274
# Mention text: aboutNeural
# Mention type: PROPER
# Representative name for the entity: computer
# Entity type: CONSUMER_GOOD
# Salience score: 0.01716756820678711
# Mention text: computer
# Mention type: COMMON
# Representative name for the entity: computer
# Entity type: CONSUMER_GOOD
# Salience score: 0.015189819037914276
# Mention text: computer
# Mention type: COMMON
# Representative name for the entity: computer
# Entity type: CONSUMER_GOOD
# Salience score: 0.015114592388272285
# Mention text: computer
# Mention type: COMMON
# Representative name for the entity: contrast
# Entity type: OTHER
# Salience score: 0.014292965643107891
# Mention text: contrast
# Mention type: COMMON
# Representative name for the entity: foundation
# Entity type: OTHER
# Salience score: 0.012757622636854649
# Mention text: foundation
# Mention type: COMMON
# Representative name for the entity: problem
# Entity type: OTHER
# Salience score: 0.008763003163039684
# Mention text: problem
# Mention type: COMMON
# Representative name for the entity: problem
# Entity type: OTHER
# Salience score: 0.008732111193239689
# Mention text: problem
# Mention type: COMMON
# Representative name for the entity: problems
# Entity type: OTHER
# Salience score: 0.008688756264746189
# Mention text: problems
# Mention type: COMMON
# Representative name for the entity: code
# Entity type: OTHER
# Salience score: 0.008110699243843555
# Mention text: code
# Mention type: COMMON
# Representative name for the entity: problems
# Entity type: OTHER
# Salience score: 0.00770624540746212
# Mention text: problems
# Mention type: COMMON
# Representative name for the entity: techniques
# Entity type: OTHER
# Salience score: 0.007619381416589022
# Mention text: techniques
# Mention type: COMMON
# Representative name for the entity: approaches
# Entity type: OTHER
# Salience score: 0.007490602787584066
# Mention text: approaches
# Mention type: COMMON
# Representative name for the entity: insights
# Entity type: OTHER
# Salience score: 0.006868291646242142
# Mention text: insights
# Mention type: COMMON
# Representative name for the entity: networks
# Entity type: OTHER
# Salience score: 0.006583426613360643
# Mention text: networks
# Mention type: COMMON
# Representative name for the entity: networks
# Entity type: OTHER
# Salience score: 0.006563130300492048
# Mention text: networks
# Mention type: COMMON
# Representative name for the entity: library
# Entity type: OTHER
# Salience score: 0.0060689859092235565
# Mention text: library
# Mention type: COMMON
# Representative name for the entity: pattern recognition problems
# Entity type: OTHER
# Salience score: 0.005886949133127928
# Mention text: pattern recognition problems
# Mention type: COMMON
# Representative name for the entity: discovery
# Entity type: EVENT
# Salience score: 0.005846068728715181
# Mention text: discovery
# Mention type: COMMON
# Representative name for the entity: problems
# Entity type: OTHER
# Salience score: 0.005835638847202063
# Mention text: problems
# Mention type: COMMON
# Representative name for the entity: book
# Entity type: WORK_OF_ART
# Salience score: 0.005438472144305706
# Mention text: book
# Mention type: COMMON
# Representative name for the entity: book
# Entity type: WORK_OF_ART
# Salience score: 0.005432658828794956
# Mention text: book
# Mention type: COMMON
# Representative name for the entity: hand
# Entity type: OTHER
# Salience score: 0.005401150323450565
# Mention text: hand
# Mention type: COMMON
# Representative name for the entity: solution
# Entity type: OTHER
# Salience score: 0.005401150323450565
# Mention text: solution
# Mention type: COMMON
# Representative name for the entity: deep learning
# Entity type: OTHER
# Salience score: 0.005393102299422026
# Mention text: deep learning
# Mention type: COMMON
# Representative name for the entity: techniques
# Entity type: OTHER
# Salience score: 0.005133836530148983
# Mention text: techniques
# Mention type: COMMON
# Representative name for the entity: language
# Entity type: OTHER
# Salience score: 0.005126408766955137
# Mention text: language
# Mention type: COMMON
# Representative name for the entity: companies
# Entity type: ORGANIZATION
# Salience score: 0.005119773093611002
# Mention text: companies
# Mention type: COMMON
# Representative name for the entity: book
# Entity type: WORK_OF_ART
# Salience score: 0.0049798255786299706
# Mention text: book
# Mention type: COMMON
# Representative name for the entity: book
# Entity type: WORK_OF_ART
# Salience score: 0.004721921402961016
# Mention text: book
# Mention type: COMMON
# Representative name for the entity: network
# Entity type: OTHER
# Salience score: 0.004559441469609737
# Mention text: network
# Mention type: COMMON
# Representative name for the entity: book
# Entity type: WORK_OF_ART
# Salience score: 0.004498462658375502
# Mention text: book
# Mention type: COMMON
# Representative name for the entity: purpose
# Entity type: OTHER
# Salience score: 0.004381818696856499
# Mention text: purpose
# Mention type: COMMON
# Representative name for the entity: speech recognition
# Entity type: OTHER
# Salience score: 0.004107493907213211
# Mention text: speech recognition
# Mention type: COMMON
# Representative name for the entity: library
# Entity type: OTHER
# Salience score: 0.003903857432305813
# Mention text: library
# Mention type: COMMON
# Representative name for the entity: library
# Entity type: LOCATION
# Salience score: 0.0039011139888316393
# Mention text: library
# Mention type: COMMON
# Representative name for the entity: understanding
# Entity type: OTHER
# Salience score: 0.0037980847992002964
# Mention text: understanding
# Mention type: COMMON
# Representative name for the entity: ideas
# Entity type: OTHER
# Salience score: 0.0037980847992002964
# Mention text: ideas
# Mention type: COMMON
# Representative name for the entity: understanding
# Entity type: OTHER
# Salience score: 0.0037980847992002964
# Mention text: understanding
# Mention type: COMMON
# Representative name for the entity: ideas
# Entity type: OTHER
# Salience score: 0.0037946244701743126
# Mention text: ideas
# Mention type: COMMON
# Representative name for the entity: tutorial
# Entity type: WORK_OF_ART
# Salience score: 0.0036484310403466225
# Mention text: tutorial
# Mention type: COMMON
# Representative name for the entity: concepts
# Entity type: OTHER
# Salience score: 0.0036436424124985933
# Mention text: concepts
# Mention type: COMMON
# Representative name for the entity: performance
# Entity type: OTHER
# Salience score: 0.003607993246987462
# Mention text: performance
# Mention type: COMMON
# Representative name for the entity: computer vision
# Entity type: OTHER
# Salience score: 0.003607993246987462
# Mention text: computer vision
# Mention type: COMMON
# Representative name for the entity: processing
# Entity type: EVENT
# Salience score: 0.003607993246987462
# Mention text: processing
# Mention type: COMMON
# Representative name for the entity: scale
# Entity type: OTHER
# Salience score: 0.003603320335969329
# Mention text: scale
# Mention type: COMMON
# Representative name for the entity: techniques
# Entity type: OTHER
# Salience score: 0.0034501447807997465
# Mention text: techniques
# Mention type: COMMON
# Representative name for the entity: laundry list
# Entity type: OTHER
# Salience score: 0.0033361611422151327
# Mention text: laundry list
# Mention type: COMMON
# Representative name for the entity: conviction
# Entity type: OTHER
# Salience score: 0.0033361611422151327
# Mention text: conviction
# Mention type: COMMON
# Representative name for the entity: principles
# Entity type: OTHER
# Salience score: 0.0033361611422151327
# Mention text: principles
# Mention type: COMMON
# Representative name for the entity: Technologies
# Entity type: OTHER
# Salience score: 0.003254813840612769
# Mention text: Technologies
# Mention type: COMMON
# Representative name for the entity: tutorials
# Entity type: WORK_OF_ART
# Salience score: 0.002848751610144973
# Mention text: tutorials
# Mention type: COMMON
# Representative name for the entity: library
# Entity type: OTHER
# Salience score: 0.002725365571677685
# Mention text: library
# Mention type: COMMON
# Representative name for the entity: insight
# Entity type: OTHER
# Salience score: 0.0026229489594697952
# Mention text: insight
# Mention type: COMMON
# Representative name for the entity: way
# Entity type: OTHER
# Salience score: 0.002503837225958705
# Mention text: way
# Mention type: COMMON
# Representative name for the entity: documentation
# Entity type: OTHER
# Salience score: 0.0025021720211952925
# Mention text: documentation
# Mention type: COMMON
# Representative name for the entity: payoff
# Entity type: OTHER
# Salience score: 0.002499092137441039
# Mention text: payoff
# Mention type: COMMON
# Representative name for the entity: approachOne
# Entity type: OTHER
# Salience score: 0.002461385913193226
# Mention text: approachOne
# Mention type: PROPER
# Representative name for the entity: technologies
# Entity type: OTHER
# Salience score: 0.0024225707165896893
# Mention text: technologies
# Mention type: COMMON
# Representative name for the entity: insights
# Entity type: OTHER
# Salience score: 0.00218201638199389
# Mention text: insights
# Mention type: COMMON
# Representative name for the entity: Facebook
# Entity type: OTHER
# Salience score: 0.0021561169996857643
# wikipedia_url: https://en.wikipedia.org/wiki/Facebook
# mid: /m/02y1vz
# Mention text: Facebook
# Mention type: PROPER
# Representative name for the entity: Microsoft
# Entity type: ORGANIZATION
# Salience score: 0.0021561169996857643
# wikipedia_url: https://en.wikipedia.org/wiki/Microsoft
# mid: /m/04sv4
# Mention text: Microsoft
# Mention type: PROPER
# Representative name for the entity: Google
# Entity type: ORGANIZATION
# Salience score: 0.0021297428756952286
# wikipedia_url: https://en.wikipedia.org/wiki/Google
# mid: /m/045c7b
# Mention text: Google
# Mention type: PROPER
# Representative name for the entity: libraries
# Entity type: LOCATION
# Salience score: 0.0017143920995295048
# Mention text: libraries
# Mention type: COMMON
# Representative name for the entity: libraries
# Entity type: LOCATION
# Salience score: 0.0017130306223407388
# Mention text: libraries
# Mention type: COMMON
# Representative name for the entity: libraries
# Entity type: LOCATION
# Salience score: 0.001692072837613523
# Mention text: libraries
# Mention type: COMMON
# Representative name for the entity: language
# Entity type: OTHER
# Salience score: 0.0015635861782357097
# Mention text: language
# Mention type: COMMON
# Representative name for the entity: language
# Entity type: OTHER
# Salience score: 0.0015623443759977818
# Mention text: language
# Mention type: COMMON
# Representative name for the entity: languages
# Entity type: OTHER
# Salience score: 0.0015056964475661516
# Mention text: languages
# Mention type: COMMON
# Representative name for the entity: data structures
# Entity type: OTHER
# Salience score: 0.0012524607591331005
# Mention text: data structures
# Mention type: COMMON
# Representative name for the entity: data structures
# Entity type: OTHER
# Salience score: 0.0012514658737927675
# Mention text: data structures
# Mention type: COMMON
# Representative name for the entity: material
# Entity type: OTHER
# Salience score: 0.001100936671718955
# Mention text: material
# Mention type: COMMON
# Representative name for the entity: syntax
# Entity type: OTHER
# Salience score: 0.0011000018566846848
# Mention text: syntax
# Mention type: COMMON
# Representative name for the entity: programming language terms
# Entity type: OTHER
# Salience score: 0.0011000018566846848
# Mention text: programming language terms
# Mention type: COMMON
# Representative name for the entity: fraction
# Entity type: OTHER
# Salience score: 0.0010991280432790518
# Mention text: fraction
# Mention type: COMMON
# Representative name for the entity: 2006
# Entity type: DATE
# Salience score: 0.0
# year: 2006
# Mention text: 2006
# Mention type: TYPE_UNKNOWN
# Representative name for the entity: 2006
# Entity type: DATE
# Salience score: 0.0
# year: 2006
# Mention text: 2006
# Mention type: TYPE_UNKNOWN
# Representative name for the entity: 2006
# Entity type: NUMBER
# Salience score: 0.0
# value: 2006
# Mention text: 2006
# Mention type: TYPE_UNKNOWN
# Representative name for the entity: 2006
# Entity type: NUMBER
# Salience score: 0.0
# value: 2006
# Mention text: 2006
# Mention type: TYPE_UNKNOWN
# Representative name for the entity: one
# Entity type: NUMBER
# Salience score: 0.0
# value: 1
# Mention text: one
# Mention type: TYPE_UNKNOWN
# Language of the text: en

# %% [markdown]
# ### Analyzing Entity Sentiment

# %%
from google.cloud import language_v1
from google.cloud.language_v1 import enums


def sample_analyze_entity_sentiment(text_content):
    """
    Analyzing Entity Sentiment in a String

    Args:
      text_content The text content to analyze
    """

    client = language_v1.LanguageServiceClient()

    # text_content = 'Grapes are good. Bananas are bad.'

    # Available types: PLAIN_TEXT, HTML
    type_ = enums.Document.Type.PLAIN_TEXT

    # Optional. If not specified, the language is automatically detected.
    # For list of supported languages:
    # https://cloud.google.com/natural-language/docs/languages
    language = "en"
    document = {"content": text_content, "type": type_, "language": language}

    # Available values: NONE, UTF8, UTF16, UTF32
    encoding_type = enums.EncodingType.UTF8

    response = client.analyze_entity_sentiment(document, encoding_type=encoding_type)
    # Loop through entitites returned from the API
    for entity in response.entities:
        print(u"Representative name for the entity: {}".format(entity.name))
        # Get entity type, e.g. PERSON, LOCATION, ADDRESS, NUMBER, et al
        print(u"Entity type: {}".format(enums.Entity.Type(entity.type).name))
        # Get the salience score associated with the entity in the [0, 1.0] range
        print(u"Salience score: {}".format(entity.salience))
        # Get the aggregate sentiment expressed for this entity in the provided document.
        sentiment = entity.sentiment
        print(u"Entity sentiment score: {}".format(sentiment.score))
        print(u"Entity sentiment magnitude: {}".format(sentiment.magnitude))
        # Loop over the metadata associated with entity. For many known entities,
        # the metadata is a Wikipedia URL (wikipedia_url) and Knowledge Graph MID (mid).
        # Some entity types may have additional metadata, e.g. ADDRESS entities
        # may have metadata for the address street_name, postal_code, et al.
        for metadata_name, metadata_value in entity.metadata.items():
            print(u"{} = {}".format(metadata_name, metadata_value))

        # Loop over the mentions of this entity in the input document.
        # The API currently supports proper noun mentions.
        for mention in entity.mentions:
            print(u"Mention text: {}".format(mention.text.content))
            # Get the mention type, e.g. PROPER for proper noun
            print(
                u"Mention type: {}".format(enums.EntityMention.Type(mention.type).name)
            )

    # Get the language of the text, which will be the same as
    # the language specified in the request or, if not specified,
    # the automatically-detected language.
    print(u"Language of the text: {}".format(response.language))

# %%
sample_analyze_entity_sentiment('Unboxing: nothing special here the box contains the phone, a charger, sim removal tool, charging cable, wired headphones. Set up: Coming from a Flagship Android device I thought it would be a very tough task to transfer data from my Android to this Iphone SE second edition.')
# Out:
# Representative name for the entity: box
# Entity type: OTHER
# Salience score: 0.22526323795318604
# Entity sentiment score: -0.30000001192092896
# Entity sentiment magnitude: 0.30000001192092896
# Mention text: box
# Mention type: COMMON
# Representative name for the entity: Unboxing
# Entity type: OTHER
# Salience score: 0.1600370854139328
# Entity sentiment score: -0.20000000298023224
# Entity sentiment magnitude: 0.20000000298023224
# Mention text: Unboxing
# Mention type: COMMON
# Representative name for the entity: nothing
# Entity type: OTHER
# Salience score: 0.1600370854139328
# Entity sentiment score: -0.4000000059604645
# Entity sentiment magnitude: 0.4000000059604645
# Mention text: nothing
# Mention type: COMMON
# Representative name for the entity: device
# Entity type: CONSUMER_GOOD
# Salience score: 0.14113789796829224
# Entity sentiment score: -0.10000000149011612
# Entity sentiment magnitude: 0.30000001192092896
# Mention text: device
# Mention type: COMMON
# Mention text: task
# Mention type: COMMON
# Representative name for the entity: charger
# Entity type: CONSUMER_GOOD
# Salience score: 0.06397014111280441
# Entity sentiment score: -0.10000000149011612
# Entity sentiment magnitude: 0.10000000149011612
# Mention text: charger
# Mention type: COMMON
# Representative name for the entity: phone
# Entity type: OTHER
# Salience score: 0.06397014111280441
# Entity sentiment score: -0.10000000149011612
# Entity sentiment magnitude: 0.10000000149011612
# Mention text: phone
# Mention type: COMMON
# Representative name for the entity: headphones
# Entity type: CONSUMER_GOOD
# Salience score: 0.044157031923532486
# Entity sentiment score: -0.20000000298023224
# Entity sentiment magnitude: 0.20000000298023224
# Mention text: headphones
# Mention type: COMMON
# Representative name for the entity: cable
# Entity type: OTHER
# Salience score: 0.043629370629787445
# Entity sentiment score: -0.20000000298023224
# Entity sentiment magnitude: 0.20000000298023224
# Mention text: cable
# Mention type: COMMON
# Representative name for the entity: sim removal tool
# Entity type: OTHER
# Salience score: 0.043629370629787445
# Entity sentiment score: -0.30000001192092896
# Entity sentiment magnitude: 0.30000001192092896
# Mention text: sim removal tool
# Mention type: COMMON
# Representative name for the entity: Android
# Entity type: CONSUMER_GOOD
# Salience score: 0.02269866317510605
# Entity sentiment score: 0.0
# Entity sentiment magnitude: 0.0
# wikipedia_url = https://en.wikipedia.org/wiki/Android_(operating_system)
# mid = /m/02wxtgw
# Mention text: Android
# Mention type: PROPER
# Mention text: Android
# Mention type: PROPER
# Representative name for the entity: data
# Entity type: OTHER
# Salience score: 0.014868264086544514
# Entity sentiment score: 0.0
# Entity sentiment magnitude: 0.0
# Mention text: data
# Mention type: COMMON
# Representative name for the entity: edition
# Entity type: WORK_OF_ART
# Salience score: 0.010427603498101234
# Entity sentiment score: 0.0
# Entity sentiment magnitude: 0.0
# Mention text: edition
# Mention type: COMMON
# Representative name for the entity: Iphone SE
# Entity type: CONSUMER_GOOD
# Salience score: 0.006174103822559118
# Entity sentiment score: 0.0
# Entity sentiment magnitude: 0.0
# Mention text: Iphone SE
# Mention type: PROPER
# Language of the text: en

# %%
sample_analyze_entity_sentiment('I bought this thinking iPhones would be good. I was wrong. This is about the least user-friendly phone I have ever had the misfortune of owning.')
# Out:
# Representative name for the entity: thinking iPhones
# Entity type: CONSUMER_GOOD
# Salience score: 0.7754953503608704
# Entity sentiment score: 0.6000000238418579
# Entity sentiment magnitude: 0.6000000238418579
# Mention text: thinking iPhones
# Mention type: COMMON
# Representative name for the entity: misfortune
# Entity type: OTHER
# Salience score: 0.15551675856113434
# Entity sentiment score: -0.800000011920929
# Entity sentiment magnitude: 0.800000011920929
# Mention text: misfortune
# Mention type: COMMON
# Representative name for the entity: phone
# Entity type: OTHER
# Salience score: 0.0689878761768341
# Entity sentiment score: 0.30000001192092896
# Entity sentiment magnitude: 0.30000001192092896
# Mention text: phone
# Mention type: COMMON
# Language of the text: en

# %% [markdown]
# ### Analyzing Entity Sentiment from Google Cloud Storage

# %%
from google.cloud import language_v1
from google.cloud.language_v1 import enums


def sample_analyze_entity_sentiment(gcs_content_uri):
    """
    Analyzing Entity Sentiment in text file stored in Cloud Storage

    Args:
      gcs_content_uri Google Cloud Storage URI where the file content is located.
      e.g. gs://[Your Bucket]/[Path to File]
    """

    client = language_v1.LanguageServiceClient()

    # gcs_content_uri = 'gs://cloud-samples-data/language/entity-sentiment.txt'

    # Available types: PLAIN_TEXT, HTML
    type_ = enums.Document.Type.PLAIN_TEXT

    # Optional. If not specified, the language is automatically detected.
    # For list of supported languages:
    # https://cloud.google.com/natural-language/docs/languages
    language = "en"
    document = {"gcs_content_uri": gcs_content_uri, "type": type_, "language": language}

    # Available values: NONE, UTF8, UTF16, UTF32
    encoding_type = enums.EncodingType.UTF8

    response = client.analyze_entity_sentiment(document, encoding_type=encoding_type)
    # Loop through entitites returned from the API
    for entity in response.entities:
        print(u"Representative name for the entity: {}".format(entity.name))
        # Get entity type, e.g. PERSON, LOCATION, ADDRESS, NUMBER, et al
        print(u"Entity type: {}".format(enums.Entity.Type(entity.type).name))
        # Get the salience score associated with the entity in the [0, 1.0] range
        print(u"Salience score: {}".format(entity.salience))
        # Get the aggregate sentiment expressed for this entity in the provided document.
        sentiment = entity.sentiment
        print(u"Entity sentiment score: {}".format(sentiment.score))
        print(u"Entity sentiment magnitude: {}".format(sentiment.magnitude))
        # Loop over the metadata associated with entity. For many known entities,
        # the metadata is a Wikipedia URL (wikipedia_url) and Knowledge Graph MID (mid).
        # Some entity types may have additional metadata, e.g. ADDRESS entities
        # may have metadata for the address street_name, postal_code, et al.
        for metadata_name, metadata_value in entity.metadata.items():
            print(u"{} = {}".format(metadata_name, metadata_value))

        # Loop over the mentions of this entity in the input document.
        # The API currently supports proper noun mentions.
        for mention in entity.mentions:
            print(u"Mention text: {}".format(mention.text.content))
            # Get the mention type, e.g. PROPER for proper noun
            print(
                u"Mention type: {}".format(enums.EntityMention.Type(mention.type).name)
            )

    # Get the language of the text, which will be the same as
    # the language specified in the request or, if not specified,
    # the automatically-detected language.
    print(u"Language of the text: {}".format(response.language))

# %%
sample_analyze_entity_sentiment('gs://buck910/text3.txt')
# Out:
# Representative name for the entity: Roger Federer
# Entity type: PERSON
# Salience score: 0.44212979078292847
# Entity sentiment score: 0.0
# Entity sentiment magnitude: 0.10000000149011612
# wikipedia_url = https://en.wikipedia.org/wiki/Roger_Federer
# mid = /m/01my95
# Mention text: rival
# Mention type: COMMON
# Mention text: Roger Federer
# Mention type: PROPER
# Representative name for the entity: Nadal
# Entity type: PERSON
# Salience score: 0.16016115248203278
# Entity sentiment score: 0.0
# Entity sentiment magnitude: 0.0
# wikipedia_url = https://en.wikipedia.org/wiki/Rafael_Nadal
# mid = /m/051q39
# Mention text: Nadal
# Mention type: PROPER
# Representative name for the entity: time
# Entity type: OTHER
# Salience score: 0.07931433618068695
# Entity sentiment score: 0.0
# Entity sentiment magnitude: 0.0
# Mention text: time
# Mention type: COMMON
# Representative name for the entity: knee surgery
# Entity type: OTHER
# Salience score: 0.07340967655181885
# Entity sentiment score: 0.0
# Entity sentiment magnitude: 0.0
# Mention text: knee surgery
# Mention type: COMMON
# Representative name for the entity: tournament
# Entity type: EVENT
# Salience score: 0.0725451186299324
# Entity sentiment score: 0.0
# Entity sentiment magnitude: 0.0
# Mention text: tournament
# Mention type: COMMON
# Representative name for the entity: draw
# Entity type: EVENT
# Salience score: 0.051339901983737946
# Entity sentiment score: 0.0
# Entity sentiment magnitude: 0.0
# Mention text: draw
# Mention type: COMMON
# Representative name for the entity: US Open
# Entity type: EVENT
# Salience score: 0.04049471765756607
# Entity sentiment score: 0.0
# Entity sentiment magnitude: 0.0
# wikipedia_url = https://en.wikipedia.org/wiki/US_Open_(tennis)
# mid = /m/0l6c9
# Mention text: US Open
# Mention type: PROPER
# Representative name for the entity: event
# Entity type: EVENT
# Salience score: 0.036210797727108
# Entity sentiment score: 0.0
# Entity sentiment magnitude: 0.0
# Mention text: event
# Mention type: COMMON
# Representative name for the entity: player
# Entity type: PERSON
# Salience score: 0.02283713035285473
# Entity sentiment score: -0.10000000149011612
# Entity sentiment magnitude: 0.10000000149011612
# Mention text: player
# Mention type: COMMON
# Representative name for the entity: Grand Slam
# Entity type: ORGANIZATION
# Salience score: 0.02155737392604351
# Entity sentiment score: 0.0
# Entity sentiment magnitude: 0.0
# wikipedia_url = https://en.wikipedia.org/wiki/Grand_Slam_(tennis)
# mid = /m/01c2c1
# Mention text: Grand Slam
# Mention type: PROPER
# Language of the text: en
